# %%
from cellpose import models
from cellpose.io import imread
import torch
from pathlib import Path
import time
import matplotlib.pyplot as plt
from skimage import exposure
import numpy as np

# %%
model = models.CellposeModel(pretrained_model="/home/clement/Documents/Sebastien/models/cellposeHMR.378670", gpu=True)

# %%
root = Path("/home/clement/Documents/Sebastien/images/")

all_files = list(root.glob("*.tiff"))
all_files = [f for f in all_files if "mask" not in str(f)]


def imadjust(img):
    p2, p98 = np.percentile(img, (1, 99))
    return exposure.rescale_intensity(img, in_range=(p2, p98))


imgs = [imread(str(f)) for f in all_files][:8]

# %%
# start = time.time()
# masks, flows, styles = model.eval(imgs)


# print("Took", time.time() - start, "seconds")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 start = time.time()
# ----> 2 masks, flows, styles = model.eval(imgs)
#       5 print("Took", time.time() - start, "seconds")
#
# File ~/miniforge-pypy3/envs/dl/lib/python3.11/site-packages/cellpose/models.py:414, in CellposeModel.eval(self, x, batch_size, resample, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, flow_threshold, cellprob_threshold, do_3D, anisotropy, stitch_threshold, min_size, niter, augment, tile, tile_overlap, bsize, interp, compute_masks, progress)
#     412 for i in iterator:
#     413     tic = time.time()
# --> 414     maski, flowi, stylei = self.eval(
#     415         x[i], batch_size=batch_size,
#     416         channels=channels[i] if channels is not None and
#     417         ((len(channels) == len(x) and
# ...

# %%
model.cp

# %%
for img in imgs:
    print(img.shape)
# Out:
# (2, 1608, 1608)
# (1608, 1608)
# (1608, 1608)
# (2, 1608, 1608)
# (1608, 1608)
# (2, 1608, 1608)
# (1608, 1608)
# (2, 1608, 1608)

# %%
plt.imshow(imgs[1])
plt.show()

# plt.imshow(masks[0])
# plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.eval(imgs[:8], batch_size=8, diameter=15, channels=[[0, 0]], tile=False, resample=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 model.eval(imgs[:8], batch_size=8, diameter=15, channels=[[0, 0]], tile=False, resample=False)
#
# File ~/miniforge-pypy3/envs/dl/lib/python3.11/site-packages/cellpose/models.py:414, in CellposeModel.eval(self, x, batch_size, resample, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, flow_threshold, cellprob_threshold, do_3D, anisotropy, stitch_threshold, min_size, niter, augment, tile, tile_overlap, bsize, interp, compute_masks, progress)
#     412 for i in iterator:
#     413     tic = time.time()
# --> 414     maski, flowi, stylei = self.eval(
#     415         x[i], batch_size=batch_size,
#     416         channels=channels[i] if channels is not None and
#     417         ((len(channels) == len(x) and
#     418           (isinstance(channels[i], list) or
# ...

# %%
imgs[0].shape
# Out:
# (1608, 1608)
