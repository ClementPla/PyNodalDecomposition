# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

# %%
df = pd.read_csv("/media/clement/USB DISK/dataMcGill/legend.csv")

col = "agSpe&activated"

df = df[(df[col] == 1) * (df["peptide"] == "OVA")]
classes = df["APL"]

sk = StratifiedShuffleSplit(n_splits=2, test_size=0.2, random_state=42)

strats = sk.split(df, classes)
index_train, index_test = list(strats)

# %%
points = [str(i) for i in range(1, 121)]
df[points]
# Out:
#               1         2         3         4         5         6         7  \
# 3437   4.037535  3.617124  3.386477  3.557191  3.953484  3.853183  3.572519
# 3439   0.853480  0.862563  0.828128  0.863375  0.839245  0.874292  0.877225
# 3440   2.331513  5.125013  3.586917  2.127225  1.549975  1.460498  1.496218
# 3441   0.976961  0.938666  0.925919  0.955596  0.966615  0.952683  0.957393
# 3442   3.808621  2.935996  2.879496  3.156508  3.301840  2.875048  2.908639
# ...         ...       ...       ...       ...       ...       ...       ...
# 36363       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 36365       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 36367       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 36368       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 36372       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...
